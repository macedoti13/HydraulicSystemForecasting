# %%
import numpy as np 
from xgboost import XGBRegressor
from pathlib import Path
import pandas as pd 
import pickle

# %%
df_path = Path("../data/curated_data/water_consumption_curated_2.parquet")
df = pd.read_parquet(df_path)
df.head()
# Out:
#             timestamp  flow_in_(l/s)  reservoir_level_(%)  ...  day  hour  second
# 1 2023-03-17 12:28:56          66.05                35.86  ...   17    12      56
# 2 2023-03-17 12:31:26          65.64                36.16  ...   17    12      26
# 3 2023-03-17 12:33:56          65.64                36.50  ...   17    12      56
# 4 2023-03-17 12:36:26          65.64                36.80  ...   17    12      26
# 5 2023-03-17 12:38:56          65.24                36.80  ...   17    12      56
#
# [5 rows x 17 columns]
